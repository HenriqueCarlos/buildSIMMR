# %%
import os

path = '/Users/Mick/Desktop/FoodCapstone/scirep-cuisines-detail/'
foodItems = []
for filename in os.listdir(path):
    if (filename[:5] == "wiki_"):
        print (filename)
        foodFile = open(path+filename,'r')
        for eachFood in foodFile:
            eachFood = eachFood.rstrip()
            foodItems.append(eachFood)
print ("total #:", len(foodItems))

foodItemsYY =[]
thisFile = open(path+"all_Ing.txt",'r')
for each in thisFile:
    each = each.split(",")[0]
    each = each.replace("_"," ")
    print (each)
    foodItemsYY.append(each)
print ("total YY#:", len(foodItemsYY))

print foodItemsYY
print foodItems
# Out:
# wiki_cheese.txt
# wiki_dairy_egg.txt
# wiki_fat_oil.txt
# wiki_fish.txt
# wiki_fruit.txt
# wiki_grain.txt
# wiki_meat.txt
# wiki_nuts_seeds.txt
# wiki_seafood.txt
# wiki_spice_herb.txt
# wiki_sweetener.txt
# wiki_vegetables.txt
# ('total #:', 477)
# salt
# water
# sugar
# geranium
# roasted hazelnut
# durian
# muscat grape
# strawberry jam
# roasted pecan
# roasted nut
# mate
# jamaican rum
# pelargonium
# sturgeon caviar
# beech
# lilac flower oil
# angelica
# kaffir lime
# emmental cheese
# jasmine tea
# soybean oil
# sheep cheese
# long pepper
# raw beef
# red algae
# pimenta
# laurel
# strawberry juice
# hop
# chamomile
# mutton
# roasted almond
# carnation
# balm
# holy basil
# rapeseed
# sea algae
# citrus peel
# blackberry brandy
# elderberry
# pork liver
# spearmint
# kohlrabi
# smoked fish
# violet
# bergamot
# carob
# sunflower oil
# jasmine
# grape brandy
# black raspberry
# ouzo
# peppermint oil
# baked potato
# leaf
# lingonberry
# condiment
# gardenia
# herring
# clove
# ...
