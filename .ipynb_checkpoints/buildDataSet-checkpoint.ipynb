# %%
import xml.etree.ElementTree as ET
import os
from tabulate import tabulate
from nltk.util import ngrams
from nltk import word_tokenize
from nltk import FreqDist
from nltk import stem
from nltk import pos_tag
from nltk import chunk
import operator

from fuzzywuzzy import process
from fuzzywuzzy import fuzz

import parseIngHelper as prsIngHp
import manageTaggedData as mngTgDat
from getLabel import buildGraph
from getLabel import displayGraph
from food import Food
from ingMap import IngMap


myStem = stem.snowball.EnglishStemmer()
units = prsIngHp.getUnitList(myStem)
# print units

# %%
def printLimit(item, num):
    if (num == 0):
        for each in item:
            print (each)
        return
    
    count = 0
    for each in item:
        count += 1
        print (each)
        if count > num:
            break

def getDictFreq(listStuff):
    dictStuff = {}
    for each in listStuff:
        if( not each in dictStuff):
            dictStuff[each] = 1
        else:
            dictStuff[each] += 1
    
    sortedStuff = sorted(dictStuff.items(), key=operator.itemgetter(1))
    
    return dictStuff, sortedStuff

def removeThesePOS(sentence, POStoRemoved):

    tokens = word_tokenize(sentence)
    tagged = pos_tag(tokens)
#     print tagged
    remainTok = [d[0] for d in tagged if not d[1] in POStoRemoved]
    return " ".join(remainTok)

class PhraseMaker:
    def __init__(self, foodDict, wordDict, minFreq, myStem):
            foodTok = foodDict.keys()
            wordTok = wordDict.keys()
            wordTok = [tk for tk in wordTok if wordDict[tk] >= minFreq]
            allTok = foodTok + wordTok
            tokPosition = {}
            for i, tk in enumerate(allTok):
                tokPosition[tk] = i
                
            self.tokPosition = tokPosition
            self.foodTok = foodTok
            self.wordTok = wordTok
            self.myStem = myStem
            self.sizeRep = len(allTok)
            self.keyVec = self.getKeyVec()
            self.sizeVec = len(allTok)+2
    
    def makePhrase(self, phrase):
        
        inFood = 0
        inWord = 0
        vec = [0 for i in range(self.sizeRep)]

        
        if len(phrase) == 0:
            vec += [inFood, inWord]
            return vec
        
        
        phrase = phrase.split()
        phraseStemmed = [myStem.stem(each) for each in phrase]
        
        for each in phraseStemmed:
            if each in self.tokPosition:
                if each in self.foodTok:
                    inFood = 1
                if each in self.wordTok:
                    inWord = 1
                    
                vec[self.tokPosition[each]] = 1
                
        vec += [inFood, inWord]
        
#         print phrase, "- food: ", inFood, " word: ", inWord        
        return vec

    def getKeyVec(self):
        
        vec = ["" for i in range(self.sizeRep)]
        for each in self.tokPosition:
            vec[self.tokPosition[each]] = each
        
        vec += ["inFood", "inWord"]
        
        return vec
    
    def showKeySparse(self, vec):
        
        assert len(self.keyVec) == len(vec)
        for i, val in enumerate(vec):
            if (val != 0):
                print self.keyVec[i],":",val

# %%
path = '/Users/Mick/Desktop/FoodCapstone/annotated_recipes/'

totalRep = 259
trainFrac = 0.7
trainSize = int(totalRep*trainFrac)

# %%
## build word bank only Ing
ingF = open('/Users/Mick/Desktop/FoodCapstone/scirep-cuisines-detail/allr_ing.uniq.txt')
standardIng = []
for each in ingF:
    each= each.rstrip()
    each = each.split()
    standardIng += each
standardIng = [myStem.stem(each) for each in standardIng]
ingDict, sortedStuff = getDictFreq(standardIng)
# getDictFreq(allFirst)
# printLimit(sortedStuff,0)

# %%
## build word bank without ing
#Main
countRep = 0
pointCheck = 0
toCheck = []
allWords = []
firstWords = []
verbose = 0

for filename in os.listdir(path):
    if filename[-4:] == ".xml":
        
        if toCheck:
            if pointCheck >= len(toCheck):
                break
            if (toCheck[pointCheck] != countRep):
                countRep += 1
                continue
            else:
                pointCheck += 1

        x, y = mngTgDat.getXandY(filename)
        ingString, xRem, yRem = mngTgDat.separateIngInstruct(x,y)

        xInstructGen, yInstructGen = mngTgDat.getOneToOneMatch(xRem,yRem, [mngTgDat.isGeneral])
        
        lenInstruct = len(xInstructGen)
        for i, each in enumerate(xInstructGen):
            ## find top words
            eachInstruct = each.rstrip().rstrip(".")
            instructTok = word_tokenize(eachInstruct)
            instructTok = [myStem.stem(tk) for tk in instructTok]
    
            withOutFirstWord = instructTok[1:]
            nonFoodTok = [etk for etk in withOutFirstWord if each not in ingDict]
            allWords += nonFoodTok
            
            ## get directions
            firstWords.append(instructTok[0])
                    
        if not toCheck:
            if (countRep == trainSize):
                break
        countRep += 1
        
if toCheck:
    trainSize = len(toCheck)
    
# allWords = [myStem.stem(each) for each in allWords]
wordDict, sortedStuff = getDictFreq(allWords)
firstWordDict, firstWordSort = getDictFreq(firstWords)

# %%
minFreq = 8
phrsMker = PhraseMaker(ingDict, wordDict, minFreq, myStem)
minFreqFirstWord = 3
phrsMkerFirstWord = PhraseMaker({},firstWordDict,minFreqFirstWord,myStem)

# %%
#build vector
countRep = 0
pointCheck = 0
toCheck = []

allX =[]
allY =[]
for filename in os.listdir(path):
    if filename[-4:] == ".xml":
        
        if toCheck:
            if pointCheck >= len(toCheck):
                break
            if (toCheck[pointCheck] != countRep):
                countRep += 1
                continue
            else:
                pointCheck += 1
        
        x, y = mngTgDat.getXandY(filename)
        xIng, xRem, yRem = mngTgDat.separateIngInstruct(x,y)
        xInstruct, yInstruct = mngTgDat.getOneToOneMatch(xRem,yRem, [mngTgDat.isGeneral])
        
        ## Labeled
        numberedInstrctXWithOri, ingMap, links = mngTgDat.processLabeledData(filename)
        
        ## pairing instruct
        instructList = ingMap.instruct
        
        if verbose == 0:
            print "Recipe#: ", countRep
            recipeName = filename.split(".")
            print "Recipe Name: ", recipeName[0]
            print
            for i, eIng in enumerate(xIng):
                print "ING#"+str(i), eIng

            print
        
        for l in links:
            print l

        ingList = []
        for eachIngProc in xIng:
            eachIngProc = prsIngHp.removeUnitsNum(myStem, eachIngProc, units)
            eachIngProc = removeThesePOS(eachIngProc, ['TO','IN','CONJ', 'CC',])
            ingList.append(eachIngProc)
        
        ## normalizd freq of word in instructions
        localWords = []
        totalWords = 0
        for eStruct in xInstruct:
            eStruct = eStruct.rstrip().rstrip(".")
            eStructSplit = word_tokenize(eStruct)
            totalWords += len(eStructSplit)
            localWords += [myStem.stem(eTk) for eTk in eStructSplit]
        localDict, localSorted = getDictFreq(localWords)
        
        for eKey in localDict:
            localDict[eKey] /= float(totalWords)
        
        Xdat = []
        Ydat = []
        
        ## interaction with Ing
        for i, eachIngProc in enumerate(ingList):
            if verbose == 1:
                print "ING#"+str(i), eachIngProc,"\n"
            
            relPosIng = i/float(len(ingList))
            interactIngFeats = []
            sentenceFeats = []
            labels = []
            
            ## per sentence
            for j, eachInstruct in enumerate(xInstruct):
                
                ## get label
                label = 0
                if j in numberedInstrctXWithOri:
                    allIngs = numberedInstrctXWithOri[j]
                    if i in allIngs[2]:
                        if verbose == 1:
                            print "********CORRECT********"
                            print  j+len(ingList) ,eachInstruct , "should be in ", instructList[i]

                        label = 1
                        
                        assert j+len(ingList) in instructList[i]
                            
                        
                labels.append(label)
                    
                ## get feature
                getFeat = 0
                if getFeat == 1:
                
                    relPosSen = j/(float(len(xInstruct)))
                    finalRes = prsIngHp.checkNGramMatch(myStem, eachInstruct,[eachIngProc])
                    ingSet = prsIngHp.getOriginWordFromSentence(eachInstruct, [(each[1],each[2],each[3],each[4]) for each in finalRes])
                    beforeWord, afterWord = prsIngHp.getBeforeAfterWord(eachInstruct, [(each[1],each[2],each[3],each[4]) for each in finalRes])

                    ingFoundAll = []
                    beforeAll = []
                    afterAll = []

                    freqScore = 0
                    rawScore = 0
                    freqAdjScore = 0
                    numHitUnique = 0
                    maxNgram = 0
                    similarPos = 0
                    corFreqEarly = 0

                    ## Sentence level feature


                    ## get feature of the interaction between ingredient and the sentence
                    for k, eachIngFound in enumerate(ingSet):

                        ## 1) Weighted Relative Frequency of the phrase found
                        eIngSplit = eachIngFound.split()
                        freqScore = sum([localDict[myStem.stem(eTk)] for eTk in eIngSplit]) / float(len(eIngSplit))

                        ## 2) Frequency adjusted max score
                        ## 3) Max raw score
                        tempScore = fuzz.ratio(eachIngFound,ingList[i])
                        invrsFreq = 1.0/freqScore
                        tempAdjScore = tempScore*invrsFreq
                        if (freqAdjScore < tempAdjScore):
                            rawScore = tempScore
                            freqAdjScore = tempAdjScore

                        ## get the word, and contexts
                            ingFoundAll = [eachIngFound]
                            beforeAll = [beforeWord[k]]
                            afterAll = [afterWord[k]]

    #                         print eachIngFound, "VS" , ingList[i], "-", tempScore
    #                         print "freqScore: ", freqAdjScore

                    ## 4) Number of hits from the sentence and ingredients
                    numHitUnique = len(set([myStem.stem(eIng) for eIng in ingSet]))

                    ## 5) Max N-gram for this sentence and ingredient
                    if (ingSet):
                        maxNgram = max([len(eIng.split()) for eIng in ingSet])

                    ## 6) How correlated is the position of ingredient and its appearance in the sentence
                    similarPos = 1- abs(relPosIng-relPosSen)

                    ## 7) How correlated is frequency of ingredient and its early appearance
                    corFreqEarly = 1 - abs(freqScore-relPosSen)

                    ## 8) Make the ingredient
                    ingMatched = phrsMker.makePhrase(" ".join(ingFoundAll))
                    # give score to isFood
                    ingMatched[-2] = ingMatched[-2]*freqAdjScore

                    ## 9) Make the context
                    contextMatched = phrsMker.makePhrase(" ".join(beforeAll + afterAll))

    #                 if (len(ingSet) != 0):
                    if verbose == 1:
                        print str(j)+')', eachInstruct, ingSet
                        print "words matched:", " ".join(ingFoundAll), "(", sum(ingMatched) ,")"
                        print "contexts:", " ".join(beforeAll + afterAll), "(",sum(contextMatched),")"
                        print "raw Score: ", rawScore
                        print "scoreFreqAdjust:", freqAdjScore
                        print "numHitUnique: ", numHitUnique
                        print "maxNgram: ", maxNgram
                        print "similar position:", similarPos
                        print "correl Freq_Early: ", corFreqEarly
                        print "foodValue: ",ingMatched[-2]
                        print

    #                 phrsMker.showKeySparse(ingMatched)
    #                 phrsMker.showKeySparse(contextMatched)

                    interactFeat = [
                        ## 1) Weighted Relative Frequency of the phrase found
                        freqScore, 
                        ## 2) Frequency adjusted max score
                        rawScore, 
                        ## 3) Max raw score
                        freqAdjScore, 

                        ## 4) Number of hits from the sentence and ingredients
                        numHitUnique, 

                        ## 5) Max N-gram for this sentence and ingredient
                        maxNgram, 

                        ## 6) How correlated is the position of ingredient and its appearance in the sentence
                        similarPos,

                        ## 7) How correlated is frequency of ingredient and its early appearance
                        corFreqEarly]

                        ## 8) Make the ingredient
                        ## 9) Make the context
                    interactFeat += ingMatched

                    interactIngFeats.append(interactFeat)

                    ## Sentence level feature

                    sentenceFeat = [] 
                    ## 10) relative position of the sentence
                    lenInstruct = len(xInstruct)
                    thisSentencePos = i/float(lenInstruct)

                    ## 11) Make first word: get direction
                    eachInstruct = eachInstruct.rstrip().rstrip(".")
                    instructTok = word_tokenize(eachInstruct)
                    instructTok = [myStem.stem(tk) for tk in instructTok]
                    direction = phrsMkerFirstWord.makePhrase(instructTok[0])

                    ## 12) Make the rest of the sentence
                    restOfSen = phrsMker.makePhrase(" ".join(instructTok[1:]))

                    ## 10) relative position of the sentence
                    sentenceFeat.append(thisSentencePos)
                    ## 11), 12)
                    sentenceFeat += direction + restOfSen

                    sentenceFeats.append(sentenceFeat)
                
            Ydat.append(labels)
            if verbose == 1:
                print "lenXdat", len(Xdat), len(interactIngFeats) , len(sentenceFeats)
            Xdat.append([interactIngFeats[ifeat]+ sentenceFeats[ifeat] for ifeat in range(len(interactIngFeats))])
        
        allX.append(Xdat)
        allY.append(Ydat)
        
        if verbose == 1:
            print "\n\n########## end of recipe ", countRep, "##########\n"
            
        if not toCheck:
            if (countRep == trainSize):
                break
        countRep += 1

        
if toCheck:
    trainSize = len(toCheck)
# Out:
# #0 1 tablespoon canola oil [16]
# #1 1 3/4 pounds boneless, skinless chicken breast or thighs, cut in chunks [16]
# #2 1 large yellow onion, chopped [18]
# #3 1 cup sliced celery [19]
# #4 1 cup thinly sliced carrots [19]
# #5 3 cups no-salt-added chopped tomatoes [19]
# #6 1 (14.25 ounce) can fat-free, less-sodium chicken broth [19]
# #7 1 (15 ounce) can no-salt-added black beans [19]
# #8 1 (15 ounce) can no salt-added navy beans [19]
# #9 1 (15 ounce) can no salt-added kidney beans [19]
# #10 1 cup dry red wine [19]
# #11 1 bay leaf [19]
# #12 1 tablespoon Italian herbs [19]
# #13 1 cup smoked chicken breast, cubed [19]
# #14 1 cup fresh Italian parsley, chopped [20]
# #15 1 cup fresh cilantro, chopped [20]
# #16 Heat oil in a large pot; brown chicken. [17]
# #17 Remove chicken and set aside. [18, 19]
# #18 Saute onions until soft, about 5 minutes. [19]
# #19 Add broth, beans, tomatoes, celery, carrots, wine, bay leaf, herbs and all the chicken; cover and simmer for 40 minutes. [20]
# #20 Add parsley, cilantro, salt, and pepper, and simmer 5 more minutes. []
# Recipe#:  0
# Recipe Name:  1-Pot-3-Bean-Chicken-Stew
#
# ING#0  1 tablespoon canola oil
# ING#1  1 34 pounds boneless, skinless chicken breast or thighs, cut in chunks
# ING#2  1 large yellow onion, chopped
# ING#3  1 cup sliced celery
# ING#4  1 cup thinly sliced carrots
# ING#5  3 cups no-salt-added chopped tomatoes
# ING#6  1 1425 ounce can fat-free, less-sodium chicken broth
# ING#7  1 15 ounce can no-salt-added black beans
# ING#8  1 15 ounce can no salt-added navy beans
# ING#9  1 15 ounce can no salt-added kidney beans
# ING#10  1 cup dry red wine
# ING#11  1 bay leaf
# ING#12  1 tablespoon Italian herbs
# ING#13  1 cup smoked chicken breast, cubed
# ING#14  1 cup fresh Italian parsley, chopped
# ING#15  1 cup fresh cilantro, chopped
#
# SPECIAL#8
#  Return chicken meat to pot just before serving.
# #0 2 tablespoons vegetable oil [10]
# #1 2 skinless chicken leg quarters [10]
# #2 1/2 cup chopped onion [11]
# #3 2 quarts water [12]
# #4 3 cubes  chicken bouillon, crumbled [12]
# #5 1 stalk celery, chopped [14]
# #6 3 carrots, chopped [14]
# #7 1 clove roasted garlic, minced [14]
# #8 salt and pepper to taste [14]
# #9 1 (12 ounce) package thin egg noodles [17]
# #10 In a large pot over medium heat, cook chicken pieces in oil until browned on both sides. [11]
# #11 Stir in onion and cook 2 minutes more. [12]
# #12 Pour in water and chicken bouillon and bring to a boil. [13, 14]
# #13 Reduce heat and simmer 45 minutes. []
# #14 Stir in celery, carrots, garlic, salt and pepper. [16, 15]
# #15 Simmer until carrots are just tender. []
# #16 Remove chicken pieces and pull the meat from the bone. [17, 18]
# #17 Stir the noodles into the pot and cook until tender, 10 minutes. [18]
# #18 Return chicken meat to pot just before serving. []
# Recipe#:  1
# Recipe Name:  A-1-Chicken-Soup
#
# ING#0  2 tablespoons vegetable oil
# ING#1  2 skinless chicken leg quarters
# ING#2  12 cup chopped onion
# ING#3  2 quarts water
# ING#4  3 cubes  chicken bouillon, crumbled
# ING#5  1 stalk celery, chopped
# ING#6  3 carrots, chopped
# ING#7  1 clove roasted garlic, minced
# ING#8  salt and pepper to taste
# ING#9  1 12 ounce package thin egg noodles
#
# SPECIAL#4
#  Spread the mixture evenly into each bread pocket.
# SPECIAL#6 Dip the slices of bread in the egg mixture.
# #0 6 (2 inch thick) slices French bread [8]
# #1 1/4 cup ricotta cheese [10]
# #2 1/4 cup cottage cheese, whipped [10]
# #3 2 tablespoons lowfat cream cheese [10]
# #4 2 teaspoons white sugar [11]
# #5 2 teaspoons vanilla extract [11]
# #6 3 cups egg substitute [13]
# #7 1/4 cup evaporated milk [13]
# #8 Cut a pocket in each slice of bread. [9, 12]
# #9 Open carefully []
# #10 In a large bowl, combine the ricotta, cottage cheese and cream cheese. [11]
# #11 Add the sugar and flavoring extract and beat until smooth. [12]
# #12 Spread the mixture evenly into each bread pocket. [14]
# #13 Beat together the egg substitutes and milk. [14]
# #14 Dip the slices of bread in the egg mixture. [17]
# #15 Heat a nonstick pan over medium-high heat. [16]
# #16 Coat with cooking spray. []
# #17 Cook the toast on each side for about 3 to 4 minutes per side until golden brown. []
# Recipe#:  2
# Recipe Name:  A-Surprise-Inside-French-Toast
#
# ING#0  6 2 inch thick slices French bread
# ING#1  14 cup ricotta cheese
# ING#2  14 cup cottage cheese, whipped
# ING#3  2 tablespoons lowfat cream cheese
# ING#4  2 teaspoons white sugar
# ING#5  2 teaspoons vanilla extract
# ING#6  3 cups egg substitute
# ING#7  14 cup evaporated milk
#
# #0 1 (10 ounce) package frozen mixed berries [3]
# #1 1 (15 ounce) can sliced peaches, drained [3]
# #2 2 tablespoons honey [3]
# #3 In a blender, combine frozen fruit, canned fruit and honey. [4]
# #4 Blend until smooth. []
# Recipe#:  3
# Recipe Name:  A-Very-Intense-Fruit-Smoothie
#
# ING#0  1 10 ounce package frozen mixed berries
# ING#1  1 15 ounce can sliced peaches, drained
# ING#2  2 tablespoons honey
#
# #0
#  2 Yukon Gold potatoes, cubed [5]
# #1 1 (5.5 ounce) package au gratin instant potato mix [5]
# #2 1 (10.5 ounce) can condensed chicken broth [5]
# #3 1 1/2 cups water [5]
# #4 1 cup heavy cream [8]
# #5 In a large saucepan or pot, combine potatoes, au gratin potato mix, chicken broth and water. [6]
# #6 Add more water to cover if necessary. [8, 7]
# #7 Cook over medium heat, stirring occasionally, until potatoes are tender, about  40 minutes. []
# #8 Stir in cream and heat through. []
# #9 Serve. []
# Recipe#:  4
# Recipe Name:  Aaahh-Potato-Soup
#
# ING#0  2 Yukon Gold potatoes, cubed
# ING#1  1 55 ounce package au gratin instant potato mix
# ING#2  1 105 ounce can condensed chicken broth
# ING#3  1 12 cups water
# ING#4  1 cup heavy cream
#
# #0 1 cup brown sugar [9]
# #1 1/2 cup chile sauce [9]
# #2 1/2 cup rum [9]
# #3 1/4 cup soy sauce [9]
# #4 1/4 cup ketchup [9]
# #5 1/4 cup Worcestershire sauce [9]
# #6 2 cloves garlic, crushed [9]
# #7 1 teaspoon ground dry mustard [9]
# #8 ground black pepper to taste [9]
# #9 In a saucepan over low heat, mix the brown sugar, chile sauce, rum, soy sauce, ketchup, Worcestershire sauce, garlic, dry mustard, and pepper. [10]
# #10 Simmer 30 minutes, stirring occasionally. []
# #11 Cool, and refrigerate until ready to use. []
# Recipe#:  5
# Recipe Name:  Absolutely-Awesome-BBQ-Sauce
#
# ING#0  1 cup brown sugar
# ING#1  12 cup chile sauce
# ING#2  12 cup rum
# ING#3  14 cup soy sauce
# ING#4  14 cup ketchup
# ING#5  14 cup Worcestershire sauce
# ING#6  2 cloves garlic, crushed
# ING#7  1 teaspoon ground dry mustard
# ING#8  ground black pepper to taste
#
# #0
#  1 (3 pound) whole chicken, cut into 8 pieces [7]
# #1 1/2 cup soy sauce [7]
# #2 3/4 cup distilled white vinegar [7]
# #3 1 bulb garlic, peeled and crushed [7]
# #4 2 tablespoons thinly sliced fresh ginger root [7]
# #5 2 bay leaves [7]
# #6 1/2 tablespoon black peppercorns [7]
# #7 Combine the chicken, soy sauce, vinegar, garlic, ginger, bay leaves and peppercorns in a Dutch oven. [8, 10, 11, 12]
# #8 Bring to a boil over medium heat. []
# #9 Once it boils, reduce heat to a simmer. []
# #10 Cover the pot and simmer for 30 minutes, basting the chicken occasionally. []
# #11 After 30 minutes, remove lid and cook until liquid has reduced to half. []
# #12 Remove chicken from the pot to a serving plate. [13]
# #13 Strain the liquid from the pot to remove all the food particles, and set aside. []
# #14 Serve chicken hot over steamed rice and drizzle with reserved sauce. []
# Recipe#:  6
# Recipe Name:  Adobo-Chicken-with-Ginger
#
# ING#0  1 3 pound whole chicken, cut into 8 pieces
# ING#1  12 cup soy sauce
# ING#2  34 cup distilled white vinegar
# ING#3  1 bulb garlic, peeled and crushed
# ING#4  2 tablespoons thinly sliced fresh ginger root
# ING#5  2 bay leaves
# ING#6  12 tablespoon black peppercorns
#
# #0 2 teaspoons peanut oil [14]
# #1 2 cloves garlic, thinly sliced [15]
# #2 2 tablespoons grated fresh ginger root [15]
# #3 1/4 cup chopped lemon grass [15]
# #4 2 teaspoons crushed red pepper [15]
# #5 1 teaspoon ground coriander [15]
# #6 1 teaspoon ground cumin [15]
# #7 1 skinless, boneless chicken breast halves - cut into thin strips [16]
# #8 1 onion, thinly sliced [16]
# #9 2 cups bok choy, shredded [17]
# #10 4 cups water [18]
# #11 1 (10 ounce) can coconut milk [18]
# #12 1/4 cup fish sauce [18]
# #13 1/4 cup chopped fresh cilantro [18]
# #14 In a large saucepan over medium heat, heat peanut oil. [15]
# #15 Stir in garlic, ginger, lemon grass, red pepper, coriander and cumin and cook until fragrant, 2 minutes. [16]
# #16 Stir in chicken and onion and cook, stirring, until chicken is white and onion is translucent, 5 minutes. [17]
# #17 Stir in bok choy and cook until it begins to wilt, 5 to 10 minutes. [18]
# #18 Stir in water, coconut milk, fish sauce and cilantro. [19]
# #19 Simmer until chicken is thoroughly cooked and flavors are well blended, 30 minutes. []
# Recipe#:  7
# Recipe Name:  Adriennes-Tom-Ka-Gai
#
# ING#0  2 teaspoons peanut oil
# ING#1  2 cloves garlic, thinly sliced
# ING#2  2 tablespoons grated fresh ginger root
# ING#3  14 cup chopped lemon grass
# ING#4  2 teaspoons crushed red pepper
# ING#5  1 teaspoon ground coriander
# ING#6  1 teaspoon ground cumin
# ING#7  1 skinless, boneless chicken breast halves - cut into thin strips
# ING#8  1 onion, thinly sliced
# ING#9  2 cups bok choy, shredded
# ING#10  4 cups water
# ING#11  1 10 ounce can coconut milk
# ING#12  14 cup fish sauce
# ING#13  14 cup chopped fresh cilantro
#
# SPECIAL#8
#  In a greased 13-in. x 9-in. x 2-in. baking dish, layer half of the noodles, halibut, white sauce and cheese.
# SPECIAL#9 Repeat layers.
# #0 6 tablespoons butter or margarine, divided [11]
# #1 1 1/2 pounds halibut steaks, bones removed and cut into 1 inch cubes [12]
# #2 2 garlic cloves, minced [12]
# #3 3/4 teaspoon dried thyme [12]
# #4 1/3 cup all-purpose flour [16]
# #5 1/2 teaspoon salt [16]
# #6 1 1/2 cups chicken broth [17]
# #7 1 cup heavy whipping cream [17]
# #8 8 ounces lasagna noodles, cooked and drained [19]
# #9 2 cups shredded Swiss cheese [19]
# #10 Minced fresh parsley [24]
# #11 In a large skillet over medium heat, melt 2 tablespoons butter. [16, 12, 15]
# #12 Add halibut, garlic and thyme. [19, 13]
# #13 Cook until fish flakes easily with a fork, about 10 minutes. []
# #14 Remove and set aside. []
# #15 Add the remaining butter to the skillet. []
# #16 Stir in flour and salt until smooth; cook and stir until golden brown. [17]
# #17 Gradually add broth and cream. [18, 19]
# #18 Bring to a boil; cook and stir for 2 minutes or until thickened. []
# #19 In a greased 13-in. x 9-in. x 2-in. baking dish, layer half of the noodles, halibut, white sauce and cheese. [20]
# #20 Repeat layers. [24, 21, 22]
# #21 Cover and bake at 350 degrees F for 20 minutes. []
# #22 Uncover; bake 20 minutes longer or until bubbly. []
# #23 Let stand 15 minutes before serving. []
# #24 Sprinkle with parsley if desired. []
# Recipe#:  8
# Recipe Name:  Alaskan-Halibut-Lasagna
#
# ING#0  6 tablespoons butter or margarine, divided
# ING#1  1 12 pounds halibut steaks, bones removed and cut into 1 inch cubes
# ING#2  2 garlic cloves, minced
# ING#3  34 teaspoon dried thyme
# ING#4  13 cup all-purpose flour
# ING#5  12 teaspoon salt
# ING#6  1 12 cups chicken broth
# ING#7  1 cup heavy whipping cream
# ING#8  8 ounces lasagna noodles, cooked and drained
# ING#9  2 cups shredded Swiss cheese
# ING#10  Minced fresh parsley
#
# #0
#  1 1/2 pounds cubed beef stew meat [10]
# #1 2 cups water [11]
# #2 1 small onion, chopped [12]
# #3 1 (28 ounce) can crushed tomatoes [12]
# #4 1 (16 ounce) package frozen mixed vegetables [12]
# #5 2 potatoes, peeled and cubed [12]
# #6 10 cubes beef bouillon, crumbled [13]
# #7 2 teaspoons ground black pepper [13]
# #8 1 tablespoon salt [13]
# #9 1 tablespoon dried basil [13]
# #10 Place beef in a slow cooker. [11]
# #11 Pour in water. [12]
# #12 Stir in onion, tomatoes, mixed vegetables and potatoes. [13]
# #13 Season with bouillon, pepper, salt and basil. [14]
# #14 Cook on low 8 hours. []
# Recipe#:  9
# Recipe Name:  Alisons-Slow-Cooker-Vegetable-Beef-Soup
#
# ING#0  1 12 pounds cubed beef stew meat
# ING#1  2 cups water
# ING#2  1 small onion, chopped
# ING#3  1 28 ounce can crushed tomatoes
# ING#4  1 16 ounce package frozen mixed vegetables
# ING#5  2 potatoes, peeled and cubed
# ING#6  10 cubes beef bouillon, crumbled
# ING#7  2 teaspoons ground black pepper
# ING#8  1 tablespoon salt
# ING#9  1 tablespoon dried basil
#
# SPECIAL#3
#  Stir into dry ingredients just until moistened.
# SPECIAL#9 Drizzle over cooled bread.
# #0 2 1/2 cups all-purpose flour [15]
# #1 1/2 cup sugar [15]
# #2 1/2 cup packed brown sugar [15]
# #3 3 teaspoons baking powder [15]
# #4 1 teaspoon salt [15]
# #5 2 (4 ounce) jars apricot baby food, divided [16]
# #6 1 egg [17]
# #7 3/4 cup milk [17]
# #8 3 tablespoons vegetable oil [17]
# #9 1 teaspoon almond extract [17]
# #10 2/3 cup sliced almonds, coarsely chopped [19]
# #11 1/2 cup diced dried apricots [19]
# #12 1/2 cup confectioners' sugar [23]
# #13 1 teaspoon milk [23]
# #14 1/8 teaspoon almond extract [23]
# #15 In a large bowl, combine the flour, sugars, baking powder and salt. [18]
# #16 Set aside 1 tablespoon baby food for glaze. [17, 23]
# #17 In another bowl, beat the egg, milk, oil, extract and remaining baby food. [18]
# #18 Stir into dry ingredients just until moistened. [19]
# #19 Fold in almonds and apricots. [24, 20, 21, 22]
# #20 Pour into a greased 9-in. x 5-in. x 3-in. loaf pan. []
# #21 Bake at 350 degrees F for 55-65 minutes or until a toothpick comes out clean. []
# #22 Cool for 10 minutes before removing from the pan to a wire rack. []
# #23 For glaze, combine the confectioners' sugar, milk, extract and reserved baby food until smooth. [24]
# #24 Drizzle over cooled bread. []
# Recipe#:  10
# Recipe Name:  Almond-Apricot-Bread
#
# ING#0  2 12 cups all-purpose flour
# ING#1  12 cup sugar
# ING#2  12 cup packed brown sugar
# ING#3  3 teaspoons baking powder
# ING#4  1 teaspoon salt
# ING#5  2 4 ounce jars apricot baby food, divided
# ING#6  1 egg
# ING#7  34 cup milk
# ING#8  3 tablespoons vegetable oil
# ING#9  1 teaspoon almond extract
# ING#10  23 cup sliced almonds, coarsely chopped
# ING#11  12 cup diced dried apricots
# ING#12  12 cup confectioners sugar
# ING#13  1 teaspoon milk
# ING#14  18 teaspoon almond extract
#
# #0
#  3/4 cup butter [5]
# #1 2 cups white sugar [5]
# #2 1 cup chopped almonds [5]
# #3 2 cups milk chocolate chips [9]
# #4 1/2 cup finely chopped almonds [10]
# #5 In a saucepan over low heat, combine the butter, sugar and 1 cup chopped almonds. [8, 9, 6, 7]
# #6 Stir constantly until mixture boils, then do not stir or shake. []
# #7 Heat to 300 to 310 degrees F (149 to 154 degrees C), or until a small amount of syrup dropped into cold water forms hard, brittle threads. []
# #8 Pour onto a large buttered cookie sheet. []
# #9 Immediately press chocolate chips onto the hot candy. As the chocolate melts, spread it into a coating over the candy. [10]
# #10 Sprinkle finely chopped almonds over the top; cool, and break into uneven pieces. []
# Recipe#:  11
# Recipe Name:  Almond-Buttercrunch
#
# ING#0  34 cup butter
# ING#1  2 cups white sugar
# ING#2  1 cup chopped almonds
# ING#3  2 cups milk chocolate chips
# ING#4  12 cup finely chopped almonds
#
# SPECIAL#2 Mix the soda and the boiling water and add to the melted butter and syrup.
# SPECIAL#3 Add butter mixture to the dry ingredients.
# #0 1 cup quick cooking oats [8]
# #1 3/4 cup flaked coconut [8]
# #2 1 cup all-purpose flour [8]
# #3 1 teaspoon baking soda [10]
# #4 1 cup white sugar [8]
# #5 1/2 cup butter [9]
# #6 1 tablespoon golden syrup [9]
# #7 2 tablespoons boiling water [10]
# #8 Mix oats, flour, sugar and coconut together. [11]
# #9 In a small saucepan over low heat, melt the syrup and butter together. [10]
# #10 Mix the soda and the boiling water and add to the melted butter and syrup. [11]
# #11 Add butter mixture to the dry ingredients. [12, 13]
# #12 Drop by teaspoons on greased cookie sheets (or baking paper). []
# #13 Bake at 350 degrees F (175 degrees C) for 18 to 20 minutes. []
# Recipe#:  12
# Recipe Name:  Anzac-Biscuits-I
#
# ING#0  1 cup quick cooking oats
# ING#1  34 cup flaked coconut
# ING#2  1 cup all-purpose flour
# ING#3  1 teaspoon baking soda
# ING#4  1 cup white sugar
# ING#5  12 cup butter
# ING#6  1 tablespoon golden syrup
# ING#7  2 tablespoons boiling water
#
# SPECIAL#6
#  Divide fruit mixture among pastry-lined pans.
# #0 2 medium cooking apples, peeled, cored, and chopped [8]
# #1 2/3 cup fresh or frozen blueberries [8]
# #2 1 tablespoon heat-stable granular sugar substitute [8]
# #3 1/2 teaspoon apple pie spice or ground allspice [8]
# #4 1 1/3 cups whole wheat pastry flour [9]
# #5 1/4 teaspoon kosher salt [9]
# #6 1/3 cup extra-virgin olive oil [10]
# #7 3 tablespoons low-fat milk [10]
# #8 In a medium bowl combine apples, blueberries, sugar substitute, and the 1/4 teaspoon apple pie spice; set aside. [14]
# #9 In another medium bowl stir together whole wheat pastry flour, kosher salt, and the 1/8 teaspoon apple pie spice. [10]
# #10 Add oil and milk all at once to flour mixture. [11, 12, 13, 14]
# #11 Stir lightly with a fork until dough comes together. []
# #12 Divide dough into 6 portions. []
# #13 Using six 3 1/2- to 4-inch individual tart pans with removable bottoms, press one dough portion on the bottom and up the side of each tart pan. []
# #14 Divide fruit mixture among pastry-lined pans. [17, 18, 15]
# #15 Place tart pans on a large baking sheet. []
# #16 Place a large piece of foil over tart pans; press down lightly around the edges to seal. []
# #17 Bake in a 375 degrees F oven for 20 minutes; remove foil. []
# #18 Bake about 20 minutes more or until fruit is tender. []
# #19 Let cool in tart pans on a wire rack for 15 minutes. []
# #20 Carefully remove sides of tart pans. []
# #21 Serve warm or cool. []
# Recipe#:  13
# Recipe Name:  Apple-Blueberry-Tarts
#
# ING#0  2 medium cooking apples, peeled, cored, and chopped
# ING#1  23 cup fresh or frozen blueberries
# ING#2  1 tablespoon heat-stable granular sugar substitute
# ING#3  12 teaspoon apple pie spice or ground allspice
# ING#4  1 13 cups whole wheat pastry flour
# ING#5  14 teaspoon kosher salt
# ING#6  13 cup extra-virgin olive oil
# ING#7  3 tablespoons low-fat milk
#
# SPECIAL#5
#  Pour 1/2 batter into pan, sprinkle 1/2 the topping over top. Pour remaining batter and top with remaining topping.
# SPECIAL#5 Pour 1/2 batter into pan, sprinkle 1/2 the topping over top. Pour remaining batter and top with remaining topping.
# SPECIAL#5 Pour 1/2 batter into pan, sprinkle 1/2 the topping over top. Pour remaining batter and top with remaining topping.
# #0 1 cup packed brown sugar [16]
# #1 1 teaspoon ground cinnamon [16]
# #2 1/2 teaspoon ground nutmeg [16]
# #3 1/2 cup chopped pecans [16]
# #4 2 cups all-purpose flour [17]
# #5 1 teaspoon baking powder [17]
# #6 1 teaspoon baking soda [17]
# #7 1/2 teaspoon salt [17]
# #8 1/2 cup butter, softened [18]
# #9 1 cup white sugar [18]
# #10 3/4 cup apple butter [18]
# #11 1 teaspoon vanilla extract [18]
# #12 1/2 cup whole bran cereal or wheat germ [18]
# #13 1 cup sour cream [19]
# #14 2 eggs, beaten [18]
# #15 Preheat oven to 350 degrees F (175 degrees C). Spray or grease one 9x13 inch pan. []
# #16 Prepare the topping by mixing together the brown sugar, cinnamon, nutmeg and chopped pecans. [20]
# #17 Sift together the flour, baking powder, baking soda and salt. [19]
# #18 Blend together butter and sugar; add eggs and beat well. Add apple butter, vanilla, wheat germ or bran cereal. Add sifted dry ingredients alternately with sour cream; mix well after each addition. [19]
# #19 Bake for 40 minutes. [20]
# #20 Pour 1/2 batter into pan, sprinkle 1/2 the topping over top. Pour remaining batter and top with remaining topping. [19]
# Recipe#:  14
# Recipe Name:  apple-butter-spice-cake
#
# ING#0  1 cup packed brown sugar
# ING#1  1 teaspoon ground cinnamon
# ING#2  12 teaspoon ground nutmeg
# ING#3  12 cup chopped pecans
# ING#4  2 cups all-purpose flour
# ING#5  1 teaspoon baking powder
# ING#6  1 teaspoon baking soda
# ING#7  12 teaspoon salt
# ING#8  12 cup butter, softened
# ING#9  1 cup white sugar
# ING#10  34 cup apple butter
# ING#11  1 teaspoon vanilla extract
# ING#12  12 cup whole bran cereal or wheat germ
# ING#13  1 cup sour cream
# ING#14  2 eggs, beaten
#
# #0
#  6 pounds tart apples, cored and sliced [5]
# #1 6 cups apple cider [6]
# #2 3 cups white sugar [10]
# #3 2 teaspoons ground cinnamon [10]
# #4 1 teaspoon ground cloves [10]
# #5 Place the apples in a Dutch oven. [6]
# #6 Pour in the cider. [8, 9, 10, 7]
# #7 Bring to a boil and cook on medium heat 30 minutes, or until soft. []
# #8 Press the softened mixture through a food mill. []
# #9 Continue cooking at a medium boil for 30 minutes, stirring occasionally. []
# #10 Mix in the sugar, cinnamon and cloves. [11, 12]
# #11 Continue cooking over low heat until the sugar dissolves, stirring frequently. []
# #12 Cook until the desired thickness has been attained. []
# #13 Refrigerate the finished apple butter in sterile containers. []
# Recipe#:  15
# Recipe Name:  Apple-Butter-V
#
# ING#0  6 pounds tart apples, cored and sliced
# ING#1  6 cups apple cider
# ING#2  3 cups white sugar
# ING#3  2 teaspoons ground cinnamon
# ING#4  1 teaspoon ground cloves
#
# SPECIAL#5 Stir in pecans. Sprinkle over apples.
# #0 2 pounds Granny Smith apples - peeled, cored and thinly sliced [11]
# #1 3/4 cup cranberries [11]
# #2 1/4 cup white sugar [11]
# #3 3 teaspoons ground cinnamon [11]
# #4 1 teaspoon ground nutmeg [11]
# #5 1/3 cup quick-cooking oats [13]
# #6 1/3 cup all-purpose flour [13]
# #7 1/2 cup packed light brown sugar [13]
# #8 1/4 cup butter, cut into pieces [14]
# #9 1/2 cup chopped pecans [15]
# #10 Preheat oven to 375 degrees F (190 degrees C.) Butter an 8 inch square baking dish. []
# #11 In a large bowl, mix together apples, cranberries, white sugar, cinnamon and nutmeg. [12, 15]
# #12 Place evenly into baking dish. []
# #13 In the same bowl, combine oats, flour and brown sugar. [14]
# #14 With a fork, mix in butter until crumbly. [15]
# #15 Stir in pecans. Sprinkle over apples. [16]
# #16 Bake in preheated oven for 40 to 50 minutes, or until topping is golden brown, and apples are tender. []
# Recipe#:  16
# Recipe Name:  Apple-Cranberry-Crisp-2
#
# ING#0  2 pounds Granny Smith apples - peeled, cored and thinly sliced
# ING#1  34 cup cranberries
# ING#2  14 cup white sugar
# ING#3  3 teaspoons ground cinnamon
# ING#4  1 teaspoon ground nutmeg
# ING#5  13 cup quick-cooking oats
# ING#6  13 cup all-purpose flour
# ING#7  12 cup packed light brown sugar
# ING#8  14 cup butter, cut into pieces
# ING#9  12 cup chopped pecans
#
# #0
#  1 gallon apple juice [5]
# #1 1 gallon apple cider [5]
# #2 3 cups white sugar [5]
# #3 8 cinnamon sticks [5]
# #4 1 (750 milliliter) bottle 190 proof grain alcohol [7]
# #5 In a large pot, combine apple juice, apple cider, sugar and cinnamon sticks. [6, 7]
# #6 Bring to a boil, then remove from heat and let cool completely. []
# #7 When juice mixture is cool, Stir in the grain alcohol. []
# Recipe#:  17
# Recipe Name:  Apple-Pie-2
#
# ING#0  1 gallon apple juice
# ING#1  1 gallon apple cider
# ING#2  3 cups white sugar
# ING#3  8 cinnamon sticks
# ING#4  1 750 milliliter bottle 190 proof grain alcohol
#
# #0 3 cups all-purpose flour [14]
# #1 3 eggs [12]
# #2 2 cups white sugar [12]
# #3 1 cup vegetable oil [12]
# #4 2 cups applesauce [13]
# #5 1 cup raisins (optional) [15]
# #6 1 teaspoon ground cinnamon [14]
# #7 1 teaspoon baking soda [14]
# #8 1/4 teaspoon baking powder [14]
# #9 1/2 cup sour cream [13]
# #10 Preheat oven to 350 degrees F (175 degrees C). []
# #11 Grease and flour two 9 x 5 inch loaf pans. []
# #12 Beat together eggs, sugar, and oil. [13]
# #13 Blend in applesauce, and then sour cream or buttermilk. [14]
# #14 Mix in flour, baking powder, soda, and cinnamon. [15]
# #15 Stir in raisins. [16, 17]
# #16 Pour batter into prepared pans. []
# #17 Bake for 80 minutes. []
# #18 Cool on wire racks. []
# Recipe#:  18
# Recipe Name:  Applesauce-Bread-I
#
# ING#0  3 cups all-purpose flour
# ING#1  3 eggs
# ING#2  2 cups white sugar
# ING#3  1 cup vegetable oil
# ING#4  2 cups applesauce
# ING#5  1 cup raisins optional
# ING#6  1 teaspoon ground cinnamon
# ING#7  1 teaspoon baking soda
# ING#8  14 teaspoon baking powder
# ING#9  12 cup sour cream
#
# #0
#  1 cup water [13]
# #1 1 1/2 tablespoons white wine vinegar [13]
# #2 3 tablespoons olive oil [13]
# #3 1/8 teaspoon cayenne pepper [13]
# #4 3/4 teaspoon dried oregano [13]
# #5 2 cloves garlic, minced [13]
# #6 3 tablespoons chopped onion [13]
# #7 3 tablespoons fresh parsley [13]
# #8 1 1/2 teaspoons salt [13]
# #9 1 tablespoon white sugar [13]
# #10 3 tablespoons wheat bran [13]
# #11 3 cups bread flour [13]
# #12 2 teaspoons active dry yeast [13]
# #13 Place ingredients in the pan of the bread machine in the order recommended by the manufacturer. [14]
# #14 Select Basic or White Cycle; press Start. []
# Recipe#:  19
# Recipe Name:  Argentine-Chimichurri-Bread
#
# ING#0  1 cup water
# ING#1  1 12 tablespoons white wine vinegar
# ING#2  3 tablespoons olive oil
# ING#3  18 teaspoon cayenne pepper
# ING#4  34 teaspoon dried oregano
# ING#5  2 cloves garlic, minced
# ING#6  3 tablespoons chopped onion
# ING#7  3 tablespoons fresh parsley
# ING#8  1 12 teaspoons salt
# ING#9  1 tablespoon white sugar
# ING#10  3 tablespoons wheat bran
# ING#11  3 cups bread flour
# ING#12  2 teaspoons active dry yeast
#
# SPECIAL#6 Shape sausage mixture around the jalapenos to form balls.
# #0 24 jalapeno peppers [9]
# #1 1 pound sausage [11]
# #2 2 cups all-purpose baking mix [11]
# #3 1 (16 ounce) package Cheddar cheese, shredded [11]
# #4 1 tablespoon crushed red pepper flakes [11]
# #5 1 tablespoon garlic salt [11]
# #6 1 (16 ounce) package Monterey Jack cheese, cubed [12]
# #7 Preheat oven to 325 degrees F (165 degrees C). []
# #8 Lightly grease a medium baking sheet. []
# #9 Cut a slit in each jalapeno pepper. [10, 12]
# #10 Remove and discard seeds and pulp. []
# #11 In a medium bowl, mix sausage, baking mix, Cheddar cheese, crushed red pepper, and garlic salt. [13]
# #12 Stuff jalapenos with the Monterey Jack cheese cubes. [13]
# #13 Shape sausage mixture around the jalapenos to form balls. [14, 15]
# #14 Arrange jalapeno balls on the prepared baking sheet. []
# #15 Bake 25 minutes in the preheated oven, until lightly browned. []
# Recipe#:  20
# Recipe Name:  Armadillo-Eggs
#
# ING#0  24 jalapeno peppers
# ING#1  1 pound sausage
# ING#2  2 cups all-purpose baking mix
# ING#3  1 16 ounce package Cheddar cheese, shredded
# ING#4  1 tablespoon crushed red pepper flakes
# ING#5  1 tablespoon garlic salt
# ING#6  1 16 ounce package Monterey Jack cheese, cubed
#
# #0
#  1 (2 to 3 pound) whole chicken, cut into pieces [14]
# #1 1 tablespoon olive oil [13]
# #2 2 onions, chopped [15]
# #3 3 cloves garlic, crushed [15]
# #4 1/2 green bell pepper, chopped [15]
# #5 1/2 (15 ounce) can tomato sauce [15]
# #6 1 pinch saffron [15]
# #7 salt to taste [15]
# #8 2 cubes  chicken bouillon [15]
# #9 1 1/2 cups uncooked white rice [16]
# #10 1 cup beer [17]
# #11 1 (15 ounce) can peas, drained [18]
# #12 1/2 red bell pepper, roasted and sliced [18]
# #13 Heat oil in a large skillet over medium high heat. [14]
# #14 Saute chicken until lightly browned; remove from skillet and set aside. [15]
# #15 Saute onion, garlic and green bell pepper until soft; stir in tomato sauce, saffron, salt and bouillon and return chicken pieces to skillet. [16]
# #16 Cook for 10 minutes, then add rice and reduce heat to low. [17]
# #17 Add beer and simmer for 8 to 10 minutes, stirring occasionally, until rice is tender. [18]
# #18 Finally, stir in peas with liquid and garnish with roasted red bell pepper. []
# Recipe#:  21
# Recipe Name:  Arroz-con-Pollo-II
#
# ING#0  1 2 to 3 pound whole chicken, cut into pieces
# ING#1  1 tablespoon olive oil
# ING#2  2 onions, chopped
# ING#3  3 cloves garlic, crushed
# ING#4  12 green bell pepper, chopped
# ING#5  12 15 ounce can tomato sauce
# ING#6  1 pinch saffron
# ING#7  salt to taste
# ING#8  2 cubes  chicken bouillon
# ING#9  1 12 cups uncooked white rice
# ING#10  1 cup beer
# ING#11  1 15 ounce can peas, drained
# ING#12  12 red bell pepper, roasted and sliced
#
# SPECIAL#2
#  Place chicken in skillet; cook, turning once to brown each side.
# SPECIAL#5 Stir in pesto and artichokes, and return chicken to pan.
# #0 4 skinless, boneless chicken breast halves [6]
# #1 salt and pepper to taste [6]
# #2 2 teaspoons olive oil [7]
# #3 1 (14.5 ounce) can diced tomatoes with green peppers and onions [10]
# #4 1/4 cup sun-dried tomato pesto [11]
# #5 1 (14 ounce) can artichoke hearts in water, drained and quartered [11]
# #6 Season both sides of chicken breasts with salt and pepper. [8]
# #7 Heat oil in a large skillet over medium-high heat. [8]
# #8 Place chicken in skillet; cook, turning once to brown each side. [11]
# #9 Remove chicken from pan, and set aside. []
# #10 Pour tomatoes into pan; cook for 1 minute, stirring constantly, and incorporating any brown bits from bottom of pan. [11]
# #11 Stir in pesto and artichokes, and return chicken to pan. [13]
# #12 Cover, and reduce heat to medium. []
# #13 Simmer for 5 to 10 minutes, or until chicken is cooked through. []
# Recipe#:  22
# Recipe Name:  Artichoke-and-Sun-dried-Tomato-Chicken
#
# ING#0  4 skinless, boneless chicken breast halves
# ING#1  Salt and pepper to taste
# ING#2  2 teaspoons olive oil
# ING#3  1 145 ounce can diced tomatoes with green peppers and onions
# ING#4  14 cup sun-dried tomato pesto
# ING#5  1 14 ounce can artichoke hearts in water, drained and quartered
#
# #0
#  1 (15 ounce) can chickpeas (garbanzo beans), drained [7]
# #1 1 clove garlic [7]
# #2 1/2 cup drained marinated artichoke hearts [7]
# #3 2 tablespoons lemon juice [7]
# #4 2 tablespoons water [7]
# #5 1 tablespoon chopped fresh parsley [11]
# #6 Quaker Quakes Ranch or Sour Cream and Onion Flavor Rice Snacks [12]
# #7 Combine all ingredients except parsley and Quaker Rice Snacks in work bowl of food processor. [8, 9, 11]
# #8 Pulse until smooth. []
# #9 Transfer to serving bowl. []
# #10 Cover and refrigerate until ready to serve. []
# #11 Stir in parsley. [12]
# #12 Dip or spread each Quakes Ranch Flavor Rice Snack with hummus. []
# Recipe#:  23
# Recipe Name:  Artichoke-Hummus
#
# ING#0  1 15 ounce can chickpeas garbanzo beans, drained
# ING#1  1 clove garlic
# ING#2  12 cup drained marinated artichoke hearts
# ING#3  2 tablespoons lemon juice
# ING#4  2 tablespoons water
# ING#5  1 tablespoon chopped fresh parsley
# ING#6  Quaker Ranch or Sour Cream and Onion Flavor Rice Snacks
#
# #0
#  3 cloves garlic, minced [7]
# #1 2 tablespoons minced fresh ginger root [7]
# #2 3/4 cup olive oil [7]
# #3 1/3 cup rice vinegar [7]
# #4 1/2 cup soy sauce [7]
# #5 3 tablespoons honey [7]
# #6 1/4 cup water [7]
# #7 In a 1 pint glass jar or larger, combine the garlic, ginger, olive oil, rice vinegar, soy sauce, honey, and water. [8, 9]
# #8 Cover the jar with a tight fitting lid, and shake well. []
# #9 Remove lid, and heat jar in the microwave for 1 minute just to dissolve the honey. []
# #10 Let cool, and shake well before serving. []
# #11 Store covered in the refrigerator. []
# Recipe#:  24
# Recipe Name:  Asian-Ginger-Dressing
#
# ING#0  3 cloves garlic, minced
# ING#1  2 tablespoons minced fresh ginger root
# ING#2  34 cup olive oil
# ING#3  13 cup rice vinegar
# ING#4  12 cup soy sauce
# ING#5  3 tablespoons honey
# ING#6  14 cup water
#
# SPECIAL#1 Crumble turkey over mixture and mix just until combined.
# #0 1 egg white [8]
# #1 1 tablespoon soy sauce [8]
# #2 1/2 cup dry bread crumbs [8]
# #3 1 tablespoon finely chopped onion [8]
# #4 1 garlic clove, minced [8]
# #5 1/4 teaspoon ground ginger [8]
# #6 1/8 teaspoon pepper [8]
# #7 12 ounces ground turkey [9]
# #8 In a bowl, combine the first seven ingredients. [9]
# #9 Crumble turkey over mixture and mix just until combined. [10, 11]
# #10 Shape into four patties. []
# #11 Cook in a nonstick skillet coated with nonstick cooking spray until no longer pink. []
# Recipe#:  25
# Recipe Name:  Asian-Turkey-Burgers
#
# ING#0  1 egg white
# ING#1  1 tablespoon soy sauce
# ING#2  12 cup dry bread crumbs
# ING#3  1 tablespoon finely chopped onion
# ING#4  1 garlic clove, minced
# ING#5  14 teaspoon ground ginger
# ING#6  18 teaspoon pepper
# ING#7  12 ounces ground turkey
#
# SPECIAL#2
#  Remove crusts from bread slices, and spread mayonnaise mixture thinly on each slice.
# SPECIAL#3 Place a spear onto the slice and roll up.
# #0 1 (10 ounce) can asparagus tips, drained [5]
# #1 1/2 cup mayonnaise [6]
# #2 2 tablespoons finely chopped onion [6]
# #3 1 pinch seasoning salt [6]
# #4 1 (1 pound) loaf soft, sliced white bread [7]
# #5 Set asparagus spears onto paper towels to absorb excess liquid. [8]
# #6 In a small bowl, mix together the mayonnaise, onion and seasoning salt. [7]
# #7 Remove crusts from bread slices, and spread mayonnaise mixture thinly on each slice. [8]
# #8 Place a spear onto the slice and roll up. [9, 10]
# #9 Cut each roll in half, and arrange on a serving tray. []
# #10 Cover with plastic wrap, and refrigerate until serving. []
# Recipe#:  26
# Recipe Name:  Asparagus-Sandwiches
#
# ING#0  1 10 ounce can asparagus tips, drained
# ING#1  12 cup mayonnaise
# ING#2  2 tablespoons finely chopped onion
# ING#3  1 pinch seasoning salt
# ING#4  1 1 pound loaf soft, sliced white bread
#
# #0 2 pounds lean ground beef [19]
# #1 1/2 large onion, diced [19]
# #2 1 tablespoon crushed red pepper [19]
# #3 3 tablespoons garlic powder [19]
# #4 1 tablespoon seasoned pepper [19]
# #5 2 (4 ounce) cans mushroom pieces, drained [21]
# #6 1 (28 ounce) can baked beans [21]
# #7 2 (15.25 ounce) cans kidney beans with liquid [21]
# #8 2 (6 ounce) cans tomato paste [21]
# #9 1/4 cup white sugar [21]
# #10 3 carrots, sliced [21]
# #11 3 stalks celery, sliced [21]
# #12 1 green bell pepper, diced [21]
# #13 1 red bell pepper, diced [21]
# #14 2 jalapeno chile peppers, diced [21]
# #15 1/4 cup Canadian beer [21]
# #16 2 tablespoons crushed red pepper [22]
# #17 hot sauce [22]
# #18 1/4 cup barbeque sauce [21]
# #19 In a large skillet over medium heat, brown ground beef together with onion, crushed red pepper, garlic powder, and seasoned pepper. [20]
# #20 Drain off the fat, and place the mixture into a slow cooker. [21]
# #21 Stir mushrooms, baked beans, kidney beans with liquid, tomato paste, sugar, carrots, celery, peppers, beer, and barbeque sauce into the slow cooker. [22]
# #22 Season with hot sauce and more crushed red pepper. [23]
# #23 Cover, and cook on Low for 4 to 5 hours. []
# Recipe#:  27
# Recipe Name:  Atomic-Canuck-Chili
#
# ING#0  2 pounds lean ground beef
# ING#1  12 large onion, diced
# ING#2  1 tablespoon crushed red pepper
# ING#3  3 tablespoons garlic powder
# ING#4  1 tablespoon seasoned pepper
# ING#5  2 4 ounce cans mushroom pieces, drained
# ING#6  1 28 ounce can baked beans
# ING#7  2 1525 ounce cans kidney beans with liquid
# ING#8  2 6 ounce cans tomato paste
# ING#9  14 cup white sugar
# ING#10  3 carrots, sliced
# ING#11  3 stalks celery, sliced
# ING#12  1 green bell pepper, diced
# ING#13  1 red bell pepper, diced
# ING#14  2 jalapeno chile peppers, diced
# ING#15  14 cup Canadian beer
# ING#16  2 tablespoons crushed red pepper
# ING#17  Hot sauce
# ING#18  14 cup barbeque sauce
#
# SPECIAL#8
#  Spread each piece with milk/nut filling and roll up like a jelly-roll, starting from the long side.
# #0 1 (8 ounce) package cream cheese, softened [7]
# #1 1/2 cup butter, softened [7]
# #2 2 cups all-purpose flour [8]
# #3 1 cup white sugar [10]
# #4 1/3 cup milk [10]
# #5 1/2 pound ground walnuts [11]
# #6 1/3 cup confectioners' sugar for decoration [20]
# #7 Beat together cream cheese and margarine until well blended. [8]
# #8 Add flour, mixing well. [9, 13, 14, 15]
# #9 Shape into a ball, cover and chill for 2 hours. []
# #10 In saucepan over medium heat, cook sugar and milk, stirring occasionally until milk boils and sugar is dissolved. [11]
# #11 Add the ground nuts. [15]
# #12 Remove from heat and let cool until mixture is of spreading consistency. []
# #13 Roll out chilled dough on lightly floured surface to a rectangle about 18 X 12 inches. []
# #14 Cut in half lengthwise. []
# #15 Spread each piece with milk/nut filling and roll up like a jelly-roll, starting from the long side. [16, 17, 18, 19, 20]
# #16 Cut each roll in half. []
# #17 Place seam side down on ungreased cookie sheets (two on a baking sheet). []
# #18 Leaving roll's shape intact, cut into slices 1/2 inch thick almost to the bottom of the roll. []
# #19 Bake at 350 degrees F (175 degrees C) for 15 to 20 minutes or till done. []
# #20 Remove from sheet and sprinkle with confectioners' sugar. [24, 21, 22, 23]
# #21 Cool on racks. []
# #22 Cut cookies all the way through. []
# #23 Refrigerate or freeze. [24]
# #24 Resprinkle with confectioners' sugar before serving. []
# Recipe#:  28
# Recipe Name:  Aunt-Mamies
#
# ING#0  1 8 ounce package cream cheese, softened
# ING#1  12 cup butter, softened
# ING#2  2 cups all-purpose flour
# ING#3  1 cup white sugar
# ING#4  13 cup milk
# ING#5  12 pound ground walnuts
# ING#6  13 cup confectioners sugar for decoration
#
# #0
#  1 large avocado, peeled and pitted [9]
# #1 2 cloves garlic, minced [9]
# #2 1 lemons, juiced [9]
# #3 1/4 cup sour cream (optional) [9]
# #4 1/2 cup chopped seeded cucumber [9]
# #5 1/2 teaspoon red pepper flakes, or to taste [11]
# #6 1 tablespoon chopped fresh cilantro [11]
# #7 1 tablespoon chopped fresh mint [11]
# #8 salt and pepper to taste [11]
# #9 In a medium bowl, combine the avocado, garlic, lemon juice, sour cream and cucumber. [10, 11]
# #10 Mash with a fork until smooth. []
# #11 Season with red pepper flakes, cilantro, mint, salt and pepper, and mix well. [12]
# #12 Cover and refrigerate for 1 hour before serving. []
# Recipe#:  29
# Recipe Name:  Avocado-Tzatziki
#
# ING#0  1 large avocado, peeled and pitted
# ING#1  2 cloves garlic, minced
# ING#2  1 lemons, juiced
# ING#3  14 cup sour cream optional
# ING#4  12 cup chopped seeded cucumber
# ING#5  12 teaspoon red pepper flakes, or to taste
# ING#6  1 tablespoon chopped fresh cilantro
# ING#7  1 tablespoon chopped fresh mint
# ING#8  salt and pepper to taste
#
# #0
#  2 slices whole wheat bread, toasted (optional) [10]
# #1 1 tablespoon mayonnaise [10]
# #2 2 teaspoons Dijon-style prepared mustard [10]
# #3 3 slices smoked turkey breast [11]
# #4 2 tablespoons guacamole [12]
# #5 1/2 cup mixed salad greens [13]
# #6 1/4 cup bean sprouts [13]
# #7 1/4 avocado - peeled, pitted and sliced [13]
# #8 3 ounces Colby-Monterey Jack cheese, sliced [13]
# #9 2 slices tomato [14]
# #10 Spread mayonnaise on one slice of toast, then spread mustard on the other. [11]
# #11 Arrange the sliced turkey on one side. [12]
# #12 Spread guacamole over the turkey. [13]
# #13 Pile on the salad greens, bean sprouts, avocado and cheese. [14]
# #14 Finish with tomato slices, then place the remaining slice of toast on top. []
# Recipe#:  30
# Recipe Name:  Awesome-Turkey-Sandwich
#
# ING#0  2 slices whole wheat bread, toasted optional
# ING#1  1 tablespoon mayonnaise
# ING#2  2 teaspoons Dijon-style prepared mustard
# ING#3  3 slices smoked turkey breast
# ING#4  2 tablespoons guacamole
# ING#5  12 cup mixed salad greens
# ING#6  14 cup bean sprouts
# ING#7  14 avocado - peeled, pitted and sliced
# ING#8  3 ounces Colby-Monterey Jack cheese, sliced
# ING#9  2 slices tomato
#
# SPECIAL#9
#  Pour dressing over the bean salad, and refrigerate for at least 1 hour before serving.
# #0 1 1/2 cups dried black-eyed peas, soaked overnight [14]
# #1 1/3 cup chopped celery, with leaves [19]
# #2 1 1/2 cups shredded carrot [19]
# #3 3/4 cup chopped fresh parsley [19]
# #4 1/2 cup chopped white onion [19]
# #5 1/8 cup chopped fresh mint [19]
# #6 1/4 cup olive oil [20]
# #7 2 oranges, juiced [20]
# #8 1/2 lemon, juiced [20]
# #9 1 garlic clove, pressed [20]
# #10 1/2 teaspoon ground coriander [20]
# #11 1/2 teaspoon salt [20]
# #12 1/8 teaspoon freshly ground black pepper [20]
# #13 1 teaspoon brown sugar [20]
# #14 Place the beans in a saucepan with enough water to cover them by one inch. [16, 18, 19, 15]
# #15 Bring beans to a slow boil. []
# #16 Reduce heat to low, and simmer until tender but not mushy (about 35 minutes). []
# #17 Set aside to cool. []
# #18 When the beans have cooled, place them in a large bowl. []
# #19 Add the celery, carrots, parsley, white onion, and mint; toss to blend. [23]
# #20 For dressing, blend olive oil, orange and lemon juice, garlic, coriander, salt, pepper, and brown sugar in a blender for 6 seconds. [21, 23]
# #21 Transfer to a small saucepan, and simmer over low heat for five minutes. []
# #22 Remove from heat, and cool. []
# #23 Pour dressing over the bean salad, and refrigerate for at least 1 hour before serving. []
# Recipe#:  31
# Recipe Name:  Babis-Bean-Salad
#
# ING#0  1 12 cups dried black-eyed peas, soaked overnight
# ING#1  13 cup chopped celery, with leaves
# ING#2  1 12 cups shredded carrot
# ING#3  34 cup chopped fresh parsley
# ING#4  12 cup chopped white onion
# ING#5  18 cup chopped fresh mint
# ING#6  14 cup olive oil
# ING#7  2 oranges, juiced
# ING#8  12 lemon, juiced
# ING#9  1 garlic clove, pressed
# ING#10  12 teaspoon ground coriander
# ING#11  12 teaspoon salt
# ING#12  18 teaspoon freshly ground black pepper
# ING#13  1 teaspoon brown sugar
#
# SPECIAL#7
#  Stir in the onion and mushrooms.
# SPECIAL#8 Mix in about 4 ounces of Swiss cheese, and all but 1 tablespoon of bacon.
# SPECIAL#12 Drain fat, and sprinkle with remaining cheese and bacon.
# #0 12 ounces chopped raw bacon [9]
# #1 1 small white onion, chopped [12]
# #2 5 button mushrooms, chopped [12]
# #3 1 1/2 pounds extra-lean ground beef [14]
# #4 1 egg [14]
# #5 1/4 cup evaporated milk [14]
# #6 6 ounces shredded Swiss cheese, divided [16]
# #7 1/2 cup corn flake crumbs [17]
# #8 Preheat oven to 350 degrees F (175 degrees C). []
# #9 Place bacon in a skillet and cook over medium heat until the pieces are browned. [10, 11]
# #10 Remove with a slotted spoon to paper towels. []
# #11 Discard all but 1 tablespoon of bacon grease. [16, 12]
# #12 Stir in onions and mushrooms, and cook until soft. [15]
# #13 Remove from heat. []
# #14 In a large bowl, stir together beef, egg, and milk. [15]
# #15 Stir in the onion and mushrooms. [16]
# #16 Mix in about 4 ounces of Swiss cheese, and all but 1 tablespoon of bacon. [17, 20]
# #17 Stir in cornflake crumbs, and mix until well blended. [18, 19, 20]
# #18 Shape into a loaf, and place in a meatloaf pan. []
# #19 Bake in a preheated oven for 1 hour. []
# #20 Drain fat, and sprinkle with remaining cheese and bacon. [21]
# #21 Return to oven, and bake until cheese is melted, about 5 minutes. []
# Recipe#:  32
# Recipe Name:  Bacon-Mushroom-Swiss-Meatloaf
#
# ING#0  12 ounces chopped raw bacon
# ING#1  1 small white onion, chopped
# ING#2  5 button mushrooms, chopped
# ING#3  1 12 pounds extra-lean ground beef
# ING#4  1 egg
# ING#5  14 cup evaporated milk
# ING#6  6 ounces shredded Swiss cheese, divided
# ING#7  12 cup corn flake crumbs
#
# #0
#  1/2 cup shredded Cheddar cheese [12]
# #1 1 tablespoon grated Parmesan cheese [12]
# #2 1 small onion, chopped [12]
# #3 1 egg [12]
# #4 1 tablespoon ketchup [12]
# #5 1 tablespoon Worcestershire sauce [12]
# #6 1/2 teaspoon salt [12]
# #7 1/8 teaspoon pepper [12]
# #8 1 pound ground beef [13]
# #9 6 slices bacon [14]
# #10 6 hamburger buns, split [17]
# #11 Preheat a grill for high heat. []
# #12 In a large bowl, mix together the Cheddar cheese, Parmesan cheese, onion, egg, ketchup, Worcestershire sauce, salt and pepper. [13]
# #13 Crumble in the ground beef, and mix together by hand. [14]
# #14 Form into 6 patties, and wrap a slice of bacon around each one. [16, 17, 15]
# #15 Secure bacon with toothpicks. []
# #16 Place patties on the grill, and cook for 5 minutes per side, or until well done. []
# #17 Remove toothpicks before serving on hamburger buns. []
# Recipe#:  33
# Recipe Name:  Bacon-Wrapped-Hamburgers
#
# ING#0  12 cup shredded Cheddar cheese
# ING#1  1 tablespoon grated Parmesan cheese
# ING#2  1 small onion, chopped
# ING#3  1 egg
# ING#4  1 tablespoon ketchup
# ING#5  1 tablespoon Worcestershire sauce
# ING#6  12 teaspoon salt
# ING#7  18 teaspoon pepper
# ING#8  1 pound ground beef
# ING#9  6 slices bacon
# ING#10  6 hamburger buns, split
#
# #0 10 hot dogs, cut into thirds [3]
# #1 15 slices bacon, cut in half [3]
# #2 1/2 cup packed brown sugar [6]
# #3 Wrap 1/2 slice of bacon around each piece of hot dog. [4, 5, 6]
# #4 Secure the bacon with a toothpick. []
# #5 Place hot dogs into a slow cooker on low heat. []
# #6 Pour brown sugar over hot dogs, let cook for 5 to 6 hours; until the bacon is cooked. []
# Recipe#:  34
# Recipe Name:  Bacon-Wrapped-Hotdogs
#
# ING#0  10 hot dogs, cut into thirds
# ING#1  15 slices bacon, cut in half
# ING#2  12 cup packed brown sugar
#
# SPECIAL#2
#  Wrap each cocktail wiener with a piece of bacon and secure with a toothpick.
# #0 1 pound sliced bacon, cut into thirds [4]
# #1 1 (14 ounce) package beef cocktail wieners [5]
# #2 3/4 cup brown sugar, or to taste [7]
# #3 Preheat the oven to 325 degrees F (165 degrees C). []
# #4 Refrigerate 2/3 of the bacon until needed. [5]
# #5 Wrap each cocktail wiener with a piece of bacon and secure with a toothpick. [7]
# #6 Place on a large baking sheet. []
# #7 Sprinkle brown sugar generously over all. [8]
# #8 Bake for 40 minutes in the preheated oven, until the sugar is bubbly. []
# #9 To serve, place the wieners in a slow cooker and keep on the low setting. []
# Recipe#:  35
# Recipe Name:  Bacon-Wrapped-Smokies
#
# ING#0  1 pound sliced bacon, cut into thirds
# ING#1  1 14 ounce package beef cocktail wieners
# ING#2  34 cup brown sugar, or to taste
#
# SPECIAL#12 Place the potato strips into the skillet, and fry until golden brown on both sides.
# #0 1 1/2 pounds russet potatoes [7]
# #1 1/2 cup all-purpose flour [12]
# #2 1 egg [12]
# #3 1 tablespoon chopped fresh parsley [12]
# #4 1/2 teaspoon salt [12]
# #5 1/4 teaspoon freshly ground nutmeg [12]
# #6 1/4 cup lard or other cooking fat [18]
# #7 Place whole potatoes in their skins into a large pot of boiling water; boil for 25 to 30 minutes. [9, 10, 11, 12]
# #8 Remove potatoes, and discard water. []
# #9 When cool enough to handle, peel potatoes, and place on a lightly floured surface. []
# #10 Mash potatoes with a rolling pin. []
# #11 Place mashed potatoes into a large bowl. []
# #12 Stir in flour, egg, parsley, salt, and nutmeg. [16, 19, 13, 14, 15]
# #13 Knead well to form a smooth dough. []
# #14 Then roll out the dough to a thickness of about 1/2 inch. []
# #15 Cut flattened dough into thin strips, about 1 1/2 inches long. []
# #16 Gently roll out the strips, or stretch them until the ends taper. []
# #17 Set aside for 15 minutes. []
# #18 In a large skillet, heat lard over medium heat. [19]
# #19 Place the potato strips into the skillet, and fry until golden brown on both sides. []
# Recipe#:  36
# Recipe Name:  Badische-Schupfnudeln-Potato-Noodles
#
# ING#0  1 12 pounds russet potatoes
# ING#1  12 cup all-purpose flour
# ING#2  1 egg
# ING#3  1 tablespoon chopped fresh parsley
# ING#4  12 teaspoon salt
# ING#5  14 teaspoon freshly ground nutmeg
# ING#6  14 cup lard or other cooking fat
#
# #0
#  1 fluid ounce dark rum [4]
# #1 1/2 fluid ounce apricot brandy [4]
# #2 3 1/2 fluid ounces fruit punch [4]
# #3 1/2 fluid ounce pina colada mix [4]
# #4 In a mixing glass combine the rum, apricot brandy, fruit punch and pina colada mix. [5]
# #5 Stir to blend and serve over ice. []
# Recipe#:  37
# Recipe Name:  Bahama-Mama-II
#
# ING#0  1 fluid ounce dark rum
# ING#1  12 fluid ounce apricot brandy
# ING#2  3 12 fluid ounces fruit punch
# ING#3  12 fluid ounce pina colada mix
#
# SPECIAL#3 Place the chicken legs in an ovenproof glass baking dish, and pour sauce over top.
# #0 1/4 cup lemon juice [9]
# #1 1/4 cup light corn syrup [9]
# #2 2 tablespoons soy sauce [9]
# #3 1 teaspoon salt [9]
# #4 1/4 teaspoon ground ginger [9]
# #5 1/4 cup corn oil [9]
# #6 1 (8 ounce) can crushed pineapple (not drained) [10]
# #7 10 chicken leg quarters [11]
# #8 Preheat oven to 350 degrees F (175 degrees C). []
# #9 Stir together lemon juice, corn syrup, soy sauce, salt, ginger, and corn oil in a bowl until smooth. [10]
# #10 Stir in the crushed pineapple with its liquid. [11]
# #11 Place the chicken legs in an ovenproof glass baking dish, and pour sauce over top. [12, 13]
# #12 Bake in preheated oven for 30 minutes, then turn the chicken over, and continue cooking until the chicken is tender, and no longer pink, about 20 minutes. []
# #13 Baste with sauce frequently while baking. []
# Recipe#:  38
# Recipe Name:  Baked-Aloha-Chicken
#
# ING#0  14 cup lemon juice
# ING#1  14 cup light corn syrup
# ING#2  2 tablespoons soy sauce
# ING#3  1 teaspoon salt
# ING#4  14 teaspoon ground ginger
# ING#5  14 cup corn oil
# ING#6  1 8 ounce can crushed pineapple not drained
# ING#7  10 chicken leg quarters
#
# #0
#  4 cups milk [10]
# #1 1/2 cup packed brown sugar [10]
# #2 2 teaspoons butter or margarine [10]
# #3 1/2 teaspoon salt [10]
# #4 1/2 teaspoon ground cinnamon [10]
# #5 2 cups old-fashioned oats [11]
# #6 2 cups chopped, peeled apples [11]
# #7 1 cup chopped walnuts [11]
# #8 1 cup raisins [11]
# #9 1 cup wheat germ [11]
# #10 In a saucepan, heat milk, brown sugar, butter, salt and cinnamon. [11]
# #11 Add remaining ingredients; mix gently. [12, 13]
# #12 Spoon into a greased 2-qt. casserole. []
# #13 Cover and bake at 350 degrees F for 45 minutes. []
# Recipe#:  39
# Recipe Name:  Baked-Apple-Oatmeal
#
# ING#0  4 cups milk
# ING#1  12 cup packed brown sugar
# ING#2  2 teaspoons butter or margarine
# ING#3  12 teaspoon salt
# ING#4  12 teaspoon ground cinnamon
# ING#5  2 cups old-fashioned oats
# ...
#
# ING#0  2 cups cherry brandy liqueur
# ING#1  1 16 ounce can frozen orange juice concentrate
# ING#2  1 16 ounce can frozen lemonade concentrate
# ING#3  2 quarts cranberry juice
# ING#4  1 2 liter bottle lemon-lime flavored carbonated beverage, chilled
#
# #0 1/4 cup butter [10]
# #1 1/2 bunch green onions, chopped [11]
# #2 1/2 cup butter [13]
# #3 2 pounds frozen crawfish, cleaned [13]
# #4 2 (10.75 ounce) cans condensed cream of potato soup [14]
# #5 1 (10.75 ounce) can condensed cream of mushroom soup [14]
# #6 1 (15.25 ounce) can whole kernel corn, drained [14]
# #7 4 ounces cream cheese, softened [14]
# #8 2 cups half-and-half cream [16]
# #9 1/2 teaspoon cayenne pepper [17]
# #10 Melt 1/4 cup of butter in a large skillet over medium heat. []
# #11 Saute green onions in butter until tender. [16]
# #12 Remove from pan, and set aside. []
# #13 In the same skillet, melt 1/2 cup of butter, and saute the crawfish for 5 minutes; set aside. [16]
# #14 In a large pot over medium heat, combine potato soup, mushroom soup, corn, and cream cheese. [16, 15]
# #15 Mix well, and bring to a slow boil. []
# #16 Stir in half-and-half, sauteed green onions, and crawfish. [17]
# #17 Season with cayenne pepper. [18]
# #18 Bring to a low boil, and simmer 5 minutes to blend flavors. []
# Recipe#:  168
# Recipe Name:  Crawfish-Chowder
#
# ING#0  14 cup butter
# ING#1  12 bunch green onions, chopped
# ING#2  12 cup butter
# ING#3  2 pounds frozen crawfish, cleaned
# ING#4  2 1075 ounce cans condensed cream of potato soup
# ING#5  1 1075 ounce can condensed cream of mushroom soup
# ING#6  1 1525 ounce can whole kernel corn, drained
# ING#7  4 ounces cream cheese, softened
# ING#8  2 cups half-and-half cream
# ING#9  12 teaspoon cayenne pepper
#
# #0
#  1 onion, chopped [5]
# #1 1 (10.75 ounce) can condensed tomato soup [6]
# #2 1 (10.75 ounce) can condensed cream of mushroom soup [6]
# #3 1 (10 ounce) can diced tomatoes with green chile peppers [6]
# #4 1 1/2 pounds crawfish, peeled [8]
# #5 In a large saucepan on medium heat, saute onion until clear. [6]
# #6 Add tomato soup, mushroom soup, and canned tomatoes. [8, 7]
# #7 Simmer for 15 minutes. []
# #8 Place the crawfish into the pan and simmer for 25 minutes. []
# Recipe#:  169
# Recipe Name:  Crawfish-Etouffee-III
#
# ING#0  1 onion, chopped
# ING#1  1 1075 ounce can condensed tomato soup
# ING#2  1 1075 ounce can condensed cream of mushroom soup
# ING#3  1 10 ounce can diced tomatoes with green chile peppers
# ING#4  1 12 pounds crawfish, peeled
#
# SPECIAL#3 Top each one with 1/4 of the mixture, spreading out to the edges.
# #0 1 small onion, finely chopped [9]
# #1 1 medium tomato, diced [9]
# #2 1 stalk celery, chopped [9]
# #3 1 green bell pepper, finely chopped [9]
# #4 1 cup shredded Cheddar cheese [9]
# #5 1/4 teaspoon chili powder [9]
# #6 1/4 teaspoon salt [9]
# #7 4 slices white bread [10]
# #8 Preheat your oven's broiler. []
# #9 In a medium bowl, stir together the onion, tomato, celery, bell pepper, cheese, chili powder and salt. [11]
# #10 Arrange slices of bread on a baking sheet or broiling pan. [11]
# #11 Top each one with 1/4 of the mixture, spreading out to the edges. [12]
# #12 Broil for 4 to 5 minutes, or until cheese melts. []
# #13 Watch closely to prevent burning. []
# #14 Serve immediately. []
# Recipe#:  170
# Recipe Name:  Crunchy-Cheese-Sandwiches
#
# ING#0  1 small onion, finely chopped
# ING#1  1 medium tomato, diced
# ING#2  1 stalk celery, chopped
# ING#3  1 green bell pepper, finely chopped
# ING#4  1 cup shredded Cheddar cheese
# ING#5  14 teaspoon chili powder
# ING#6  14 teaspoon salt
# ING#7  4 slices white bread
#
# #0
#  3 ounces reduced fat cream cheese, softened [9]
# #1 1 cup fat-free milk [10]
# #2 1 cup egg substitute [10]
# #3 1/4 teaspoon pepper [10]
# #4 3 cups shredded reduced-fat Cheddar cheese [11]
# #5 1 (10 ounce) package frozen chopped spinach, thawed and squeezed dry [11]
# #6 1 cup frozen chopped broccoli, thawed and well drained [11]
# #7 1 small onion, finely chopped [11]
# #8 5 fresh mushrooms, sliced [11]
# #9 In a small mixing bowl, beat cream cheese. [10]
# #10 Add milk, egg substitute and pepper; beat until smooth. [11]
# #11 Stir in remaining ingredients. [12, 13]
# #12 quiche pan coated with nonstick cooking spray. []
# #13 Bake at 350 degrees F for 45-50 minutes or until a knife inserted near the center comes out clean. []
# Recipe#:  171
# Recipe Name:  Crustless-Spinach-Quiche-2
#
# ING#0  3 ounces reduced fat cream cheese, softened
# ING#1  1 cup fat-free milk
# ING#2  1 cup egg substitute
# ING#3  14 teaspoon pepper
# ING#4  3 cups shredded reduced-fat Cheddar cheese
# ING#5  1 10 ounce package frozen chopped spinach, thawed and squeezed dry
# ING#6  1 cup frozen chopped broccoli, thawed and well drained
# ING#7  1 small onion, finely chopped
# ING#8  5 fresh mushrooms, sliced
#
# SPECIAL#6
#  Add spinach mixture and stir to blend.
# #0 1 tablespoon vegetable oil [9]
# #1 1 onion, chopped [10]
# #2 1 (10 ounce) package frozen chopped spinach, thawed and drained [11]
# #3 5 eggs, beaten [12]
# #4 3 cups shredded Muenster cheese [12]
# #5 1/4 teaspoon salt [12]
# #6 1/8 teaspoon ground black pepper [12]
# #7 Preheat oven to 350 degrees F (175 degrees C). []
# #8 Lightly grease a 9 inch pie pan. []
# #9 Heat oil in a large skillet over medium-high heat. []
# #10 Add onions and cook, stirring occasionally, until onions are soft. [11]
# #11 Stir in spinach and continue cooking until excess moisture has evaporated. [13]
# #12 In a large bowl, combine eggs, cheese, salt and pepper. [13]
# #13 Add spinach mixture and stir to blend. [14, 15]
# #14 Scoop into prepared pie pan. []
# #15 Bake in preheated oven until eggs have set, about 30 minutes. []
# #16 Let cool for 10 minutes before serving. []
# Recipe#:  172
# Recipe Name:  Crustless-Spinach-Quiche
#
# ING#0  1 tablespoon vegetable oil
# ING#1  1 onion, chopped
# ING#2  1 10 ounce package frozen chopped spinach, thawed and drained
# ING#3  5 eggs, beaten
# ING#4  3 cups shredded Muenster cheese
# ING#5  14 teaspoon salt
# ING#6  18 teaspoon ground black pepper
#
# SPECIAL#2 Peel cucumbers if desired thinly slice and place on six slices of bread.
# SPECIAL#3 Top with remaining bread.
# #0 1 (8 ounce) package cream cheese spread [4]
# #1 2 teaspoons ranch salad dressing mix [4]
# #2 12 slices pumpernickel rye bread [5]
# #3 2 medium cucumbers [6]
# #4 In a bowl, combine cream cheese and dressing mix. [5]
# #5 Spread on one side of each slice of bread. [6]
# #6 Peel cucumbers if desired thinly slice and place on six slices of bread. [7]
# #7 Top with remaining bread. []
# #8 Serve immediately. []
# Recipe#:
#  173
# Recipe Name:  Cucumber-Sandwiches
#
# ING#0  1 8 ounce package cream cheese spread
# ING#1  2 teaspoons ranch salad dressing mix
# ING#2  12 slices pumpernickel rye bread
# ING#3  2 medium cucumbers
#
# SPECIAL#3 Add to creamed mixture and mix well.
# SPECIAL#7 Chill for several hours.
# SPECIAL#14 Place small heart on top and press lightly to secure.
# #0 1 cup butter [11]
# #1 1 cup white sugar [11]
# #2 1 egg [12]
# #3 1 1/2 teaspoons vanilla extract [12]
# #4 2 1/2 cups sifted all-purpose flour [13]
# #5 1/2 teaspoon salt [13]
# #6 1 cup rolled oats [15]
# #7 1/4 teaspoon peppermint extract [17]
# #8 3 drops red food coloring [17]
# #9 2 tablespoons confectioners' sugar [20]
# #10 5 (1.5 ounce) bars milk chocolate candy [24]
# #11 In a medium bowl, cream together butter or margarine and white sugar until light and fluffy. [12]
# #12 Blend in egg and vanilla. [14]
# #13 Sift together flour and salt. [14]
# #14 Add to creamed mixture and mix well. [15]
# #15 Stir in oats. [16]
# #16 Divide dough in half. [17, 18]
# #17 Add peppermint extract and a few drops of food color to half of dough. [18]
# #18 Chill for several hours. [24, 20, 21, 22, 23]
# #19 Preheat oven to 350 degrees F (175 degrees C). []
# #20 Roll out each half of dough to 1/8 inch thickness on surface sprinkled lightly with confectioners' sugar. []
# #21 Cut out half of each color with the 2 1/2 inch heart shaped cookie cutter, and half with a 1 1/2 inch cookie cutter. []
# #22 Place them on unprepared cookie sheets. []
# #23 Bake for 10 to 12 minutes in the preheated oven. []
# #24 Remove from oven and place 1 one square (1/8) of a chocolate bar onto the center of each large heart. [25]
# #25 Place small heart on top and press lightly to secure. []
# #26 Transfer to rack to cool. []
# Recipe#:  174
# Recipe Name:  Cupids-Cookies
#
# ING#0  1 cup butter
# ING#1  1 cup white sugar
# ING#2  1 egg
# ING#3  1 12 teaspoons vanilla extract
# ING#4  2 12 cups sifted all-purpose flour
# ING#5  12 teaspoon salt
# ING#6  1 cup rolled oats
# ING#7  14 teaspoon peppermint extract
# ING#8  3 drops red food coloring
# ING#9  2 tablespoons confectioners sugar
# ING#10  5 15 ounce bars milk chocolate candy
#
# #0
#  3 cups cooked, mashed winter squash [7]
# #1 1 1/2 tablespoons curry powder [7]
# #2 2 tablespoons butter or trans fat-free margarine [7]
# #3 2 tablespoons maple syrup [7]
# #4 1/2 teaspoon Salt, to taste [7]
# #5 1/4 teaspoon cayenne pepper to taste [7]
# #6 3 tablespoons sweetened coconut flakes, toasted (optional) [9]
# #7 In a medium bowl, combine first six ingredients. [8, 9]
# #8 Microwave on high until heated through, about 5 minutes. []
# #9 Sprinkle on coconut, if desired. []
# #10 Serve. []
# Recipe#:  175
# Recipe Name:  Curried-Winter-Squash
#
# ING#0  3 cups cooked, mashed winter squash
# ING#1  1 12 tablespoons curry powder
# ING#2  2 tablespoons butter or trans fat-free margarine
# ING#3  2 tablespoons maple syrup
# ING#4  12 teaspoon Salt, to taste
# ING#5  14 teaspoon cayenne pepper to taste
# ING#6  3 tablespoons sweetened coconut flakes, toasted optional
#
# SPECIAL#3 Generously coat the roast with the mustard mixture.
# #0 1 1/3 cups yellow mustard [3]
# #1 2 (1 ounce) envelopes dry onion soup mix [3]
# #2 1 (5 pound) beef rump roast [5]
# #3 In a small bowl, mix together the mustard and onion soup mix. [6]
# #4 Lay out two long sheets of aluminum foil crosswise. []
# #5 Pat the roast dry, and place in the center of the foil. [6]
# #6 Generously coat the roast with the mustard mixture. [10, 11, 13, 7]
# #7 Wrap the foil tightly around the roast, then apply one more piece of foil to really seal it in so that the roast can be rotated without all of the juices spilling out. []
# #8 Prepare an outdoor grill for indirect heat. []
# #9 For charcoal, light the coals, then move to one side of the grill. []
# #10 Place the roast on the grill, and cover. []
# #11 Cook for about 2 hours, turning every 30 to 45 minutes, or until the internal temperature is at least 145 degrees F (63 degrees C). []
# #12 Let stand for about 10 minutes before carving. []
# #13 Place on a deep serving plate before unwrapping so you can be sure to save the juices and mustard rub to slather on the beef slices. []
# Recipe#:  176
# Recipe Name:  Dads-BBQ-Roast
#
# ING#0  1 13 cups yellow mustard
# ING#1  2 1 ounce envelopes dry onion soup mix
# ING#2  1 5 pound beef rump roast
#
# #0
#  1 (3 ounce) package cream cheese, softened [10]
# #1 1 egg [10]
# #2 1 medium onion, finely chopped [10]
# #3 1/2 cup dry bread crumbs [10]
# #4 1 1/2 teaspoons dried parsley flakes [10]
# #5 1/2 teaspoon seasoned salt [10]
# #6 1/4 teaspoon pepper [10]
# #7 1 pound ground beef [11]
# #8 1 pound bulk pork sausage [11]
# #9 8 hamburger buns, split [14]
# #10 In a bowl, combine the first seven ingredients. [11]
# #11 Crumble beef and sausage over mixture; mix well. [12, 13, 14]
# #12 Shape into eight patties. []
# #13 Grill, uncovered, over medium-hot heat for 4-6 minutes on each side or until no longer pink. []
# #14 Serve on buns. []
# Recipe#:  177
# Recipe Name:  Dads-Best-Burgers
#
# ING#0  1 3 ounce package cream cheese, softened
# ING#1  1 egg
# ING#2  1 medium onion, finely chopped
# ING#3  12 cup dry bread crumbs
# ING#4  1 12 teaspoons dried parsley flakes
# ING#5  12 teaspoon seasoned salt
# ING#6  14 teaspoon pepper
# ING#7  1 pound ground beef
# ING#8  1 pound bulk pork sausage
# ING#9  8 hamburger buns, split
#
# SPECIAL#2
#  Add enough remaining all-purpose flour to form a soft dough.
# #0 1 (.25 ounce) package active dry yeast [7]
# #1 2 cups warm water (110 degrees to 115 degrees), divided [7]
# #2 1/3 cup sugar [8]
# #3 2 tablespoons vegetable oil [8]
# #4 1 tablespoon salt [8]
# #5 1/2 cup rye or whole wheat flour [8]
# #6 5 1/2 cups all-purpose flour [8]
# #7 In a large mixing bowl, dissolve yeast in 1/2 cup of water. [8]
# #8 Add sugar, oil, salt, rye or whole wheat flour, 3 cups all-purpose flour, and remaining water; beat until smooth. [9]
# #9 Add enough remaining all-purpose flour to form a soft dough. [10, 11, 13, 14, 15, 16, 18]
# #10 Turn onto a floured surface; knead until smooth and elastic, about 6-8 minutes. []
# #11 Place in a greased bowl, turning once to grease top. []
# #12 Cover and let rise in a warm place until doubled, about 1 hour. []
# #13 Punch dough down. []
# #14 Divide in half. []
# #15 On a greased baking sheet, flatten each half to 1-in. []
# #16 Pierce each loaf several times with a fork. []
# #17 Cover and let rise in a warm place until nearly doubled, about 30 minutes. []
# #18 Bake at 375 degrees F for 25-30 minutes or until golden brown. []
# Recipe#:  178
# Recipe Name:  Dads-Flat-Bread
#
# ING#0  1 25 ounce package active dry yeast
# ING#1  2 cups warm water 110 degrees to 115 degrees, divided
# ING#2  13 cup sugar
# ING#3  2 tablespoons vegetable oil
# ING#4  1 tablespoon salt
# ING#5  12 cup rye or whole wheat flour
# ING#6  5 12 cups all-purpose flour
#
# #0 3 tablespoons Jamaican jerk seasoning blend [7]
# #1 3 tablespoons vegetable oil [7]
# #2 3 cloves garlic, diced [7]
# #3 1 (1 inch) piece peeled fresh ginger, diced [7]
# #4 1 bunch green onions, chopped [7]
# #5 12 slices pickled jalapeno peppers [7]
# #6 4 pounds chicken wings [8]
# #7 Place the jerk seasoning, oil, garlic, ginger, green onions, and jalapeno slices in a blender, and blend until thick and smooth. [8]
# #8 Dunk wings in the mixture, and arrange in single layer on baking sheets. [11]
# #9 Cover with aluminum foil, and refrigerate 8 hours, or overnight. []
# #10 Preheat oven to 300 degrees F (150 degrees C). []
# #11 Bake wings 2 hours in the preheated oven. []
# Recipe#:  179
# Recipe Name:  Dads-Kickin-Jamaican-Wings-Mon
#
# ING#0  3 tablespoons Jamaican jerk seasoning blend
# ING#1  3 tablespoons vegetable oil
# ING#2  3 cloves garlic, diced
# ING#3  1 1 inch piece peeled fresh ginger, diced
# ING#4  1 bunch green onions, chopped
# ING#5  12 slices pickled jalapeno peppers
# ING#6  4 pounds chicken wings
#
# #0
#  1 cup dates, pitted and chopped [9]
# #1 1 cup dark brown sugar [9]
# #2 1/4 cup margarine [9]
# #3 1 cup boiling water [9]
# #4 1 3/4 cups self-rising flour [11]
# #5 1 teaspoon baking soda [11]
# #6 2 teaspoons vanilla extract [11]
# #7 Preheat oven to 400 degrees F (200 degrees C). []
# #8 Grease and flour a 9x5 inch loaf pan. []
# #9 In a large bowl, combine dates, brown sugar, margarine and boiling water. [11]
# #10 Let stand 15 minutes. []
# #11 Stir in flour, soda and vanilla. [12, 13]
# #12 Pour batter into prepared pan. []
# #13 Bake in the preheated oven for 45 minutes. []
# #14 Allow to cool. []
# Recipe#:  180
# Recipe Name:  Date-Loaf-Cake
#
# ING#0  1 cup dates, pitted and chopped
# ING#1  1 cup dark brown sugar
# ING#2  14 cup margarine
# ING#3  1 cup boiling water
# ING#4  1 34 cups self-rising flour
# ING#5  1 teaspoon baking soda
# ING#6  2 teaspoons vanilla extract
#
# #0 2 cups sugar [10]
# #1 2 cups all-purpose flour [10]
# #2 2 teaspoons baking powder [10]
# #3 1/4 teaspoon salt [10]
# #4 2 cups chopped dates [10]
# #5 2 cups chopped walnuts or pecans [10]
# #6 4 eggs, lightly beaten [11]
# #7 2 tablespoons butter, melted [11]
# #8 1 teaspoon vanilla extract [11]
# #9 confectioners' sugar [15]
# #10 In a large bowl, combine the sugar, flour, baking powder, salt, dates and nuts. [11]
# #11 Add the eggs, butter and vanilla; stir just until dry ingredients are moistened (batter will be very stiff). [12, 13, 14, 15]
# #12 Spread in a greased 15-in. []
# #13 Bake at 350 degrees F for 20-25 minutes or until golden brown. []
# #14 Cool bars on a wire rack. []
# #15 Dust with confectioners' sugar. []
# Recipe#:  181
# Recipe Name:  Date-Nut-Bars
#
# ING#0  2 cups sugar
# ING#1  2 cups all-purpose flour
# ING#2  2 teaspoons baking powder
# ING#3  14 teaspoon salt
# ING#4  2 cups chopped dates
# ING#5  2 cups chopped walnuts or pecans
# ING#6  4 eggs, lightly beaten
# ING#7  2 tablespoons butter, melted
# ING#8  1 teaspoon vanilla extract
# ING#9  confectioners sugar

# %%
# getDictFreq(allFirst)
# printLimit(firstWordSort,0)

# %%
# for h, recipe in enumerate(allX):
#     print "########## new recipe #############"
#     Xdat = allX[h]
#     Ydat = allY[h]
#     for i, each in enumerate(Xdat):
#         print "New ing"
#         print
#         for j, eeach in enumerate(each):
#             print "new sen", Ydat[i][j]
#             print eeach
#         print

# %%
# import pickle
# pickle.dump( allX, open( "xTrain.p", "wb" ) )
# pickle.dump( allY, open( "yTrain.p", "wb" ) )
